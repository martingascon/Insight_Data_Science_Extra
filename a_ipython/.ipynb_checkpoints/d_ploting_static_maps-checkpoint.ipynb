# %%
import matplotlib.image as mpimg
import googlemaps
import urllib
import gmaps 
# %matplotlib inline
import sys
import pandas as pd
import csv
import sys
import numpy as np
import psycopg2
from pandas import DataFrame
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists
import matplotlib.pyplot as plt

# %%
maxInt = sys.maxsize
decrement = True

while decrement:
    # decrease the maxInt value by factor 10 
    # as long as the OverflowError occurs.
    decrement = False
    try:
        csv.field_size_limit(maxInt)
    except OverflowError:
        maxInt = int(maxInt/10)
        decrement = True

# %% [markdown]
# # let's connect to the databse to see load the data

# %%
# Connect to the DB first
dbname = 'gdelt_db'
username = 'martin'
my_password='po$t'
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,my_password,dbname))

# %%
columns = ['DATE','NUMARTS', 'COUNTTYPE', 'NUMBER'\
           ,'OBJECTTYPE', 'GEO_TYPE', 'GEO_FULLNAME'\
           , 'GEO_COUNTRYCODE', 'GEO_ADM1CODE', 'GEO_LAT', 'GEO_LONG']

df = pd.DataFrame(columns=columns)

# %%
try:
    db_con = None
    db_con = psycopg2.connect(database=dbname, user=username, password=my_password)
    #cursor = db_con.cursor()
    #cursor.execute("SELECT * FROM gdelt;")
    #print(cursor.fetchone())
    #data = cursor.fetchall()
    # let's import the ones from Mx only
    df = pd.read_sql_query("SELECT edate,gname,numarts,number,otype,geolat,geolon FROM gdelt where number='15' and gtype='4';", engine)
    #df = pd.read_sql_query("SELECT * FROM gdelt;", engine)   
except psycopg2.DatabaseError as e: 
    print ('Error %s' % e)
    sys.exit(1)
finally:
    if db_con:
        db_con.close()
df.head(100)
# Out:
#         edate                                              gname  numarts  \
# 0  2016-01-01                           Cairo, Al Qahirah, Egypt        6
# 1  2016-01-01             Kafr El-sheikh, Kafr Ash Shaykh, Egypt        6
# 2  2016-01-01              Sunshine Coast, Queensland, Australia        6
# 3  2016-01-01           Hancock Park, New South Wales, Australia       11
# 4  2016-01-01                 Nile River, Egypt (General), Egypt      160
# 5  2016-01-01                          Timolin, Kildare, Ireland        9
# 6  2016-01-01                Vancouver, British Columbia, Canada        4
# 7  2016-01-02                           Cairo, Al Qahirah, Egypt        5
# 8  2016-01-02                         Tel Aviv, Tel Aviv, Israel       17
# 9  2016-01-02                       Mogadishu, Banaadir, Somalia       27
# 10 2016-01-02           Hancock Park, New South Wales, Australia       16
# 11 2016-01-02                 Nile River, Egypt (General), Egypt       43
# ...

# %%
# Let's define the center and the coordinate box
Center = [df.geolat.mean(),df.geolon.mean()]
StartingLat = max(df.geolat)
StartingLon = max(df.geolon)
EndingLat   = min(df.geolat)
EndingLon  = min(df.geolon)

print "Max/Min Latitude",StartingLat," ",EndingLat
print "Max/Min Longitude",StartingLon," ",EndingLon
print "Center",Center[0]," ",Center[1]
# Out:
# Max/Min Latitude 82.4333   -54.4
# Max/Min Longitude 179.483   -176.633
# Center 23.6491662927   45.8075598016

# %%
def get_static_google_map(filename_wo_extension, center=None, zoom=None, imgsize="500x500", imgformat="png",
                          maptype="roadmap", markers=None ):  
    # assemble the URL
    request =  "http://maps.google.com/maps/api/staticmap?" # base URL, append query params, separated by &
    # if center and zoom  are not given, the map will show all marker locations
    if center != None:
        request += "center=%s&" % center
    #if center != None:
    #    request += "zoom=%i&" % zoom  # zoom 0 (all of the world scale ) to 22 (single buildings scale)
    request += "size=%ix%i&" % (imgsize)  # tuple of ints, up to 640 by 640
    request += "format=%s&" % imgformat
    request += "maptype=%s&" % maptype  # roadmap, satellite, hybrid, terrain
    # add markers (location and style)
    if markers != None:
        for marker in markers:
                request += "%s&" % marker
    request += "sensor=false&"    
    #print request
    MapImageReturn = urllib.urlretrieve(request, "/Users/martin/Downloads/google_map_example.png")[0]
    GMImageArray = mpimg.imread(MapImageReturn)
    imgplot = plt.imshow(GMImageArray)

# %% [markdown]
# # Make the markers

# %%
marker_list = []

#marker_list.append("markers=color:blue|label:S|11211|11206|11222") # blue S at several zip code's centers
#marker_list.append("markers=size:tiny|label:B|color:0xFFFF00|40.702147,-74.015794|") # tiny yellow B at lat/long
#marker_list.append("markers=size:mid|color:red|label:6|Brooklyn+Bridge,New+York,NY") # mid-sized red 6 at search location
# see http://code.google.com/apis/maps/documentation/staticmaps/#Markers
for i in range(rows):
    latlon = ""
    latlon = "%s," % df.geolat[i]
    latlon += "%s" % df.geolon[i]
    if df.number[i]<8:
        marker = "markers=size:mid|label:%s|color:blue|" % df.numarts[i]
    elif df.number[i]<20:
        marker = "markers=size:mid|label:%s|color:yellow|" % df.numarts[i]
    else:
        marker = "markers=size:mid|label:%2.0s|color:red|" % df.numarts[i]
    marker += "%s|" % latlon
    #print latlon
    marker_list.append(marker)
    
print marker_list[0]
# Out:
# markers=size:mid|label:6|color:yellow|30.05,31.25|

# %%
 
ctr = "%s," % 0
ctr += "%s" % 0
print ctr
# make a map around a center
get_static_google_map("google_map_example1", center=ctr, zoom=0, imgsize=(520,260),
                          imgformat="jpeg", maptype="terrain", markers=marker_list[1:30])
# Out:
# 0,0

# %%
GMapsInstance = googlemaps.Client(key='AIzaSyCO7rC1zzcABqmp2cGf30vRpusYDych5rA')
MapZoom=1
StaticImageEdgeSize_x=600
StaticImageEdgeSize_y=600
MapImgageURL = "https://maps.googleapis.com/maps/api/staticmap?center=%s,%s&zoom=%i&size=%ix%i&sensor=false" % (StartingLat, StartingLon, MapZoom, StaticImageEdgeSize_x, StaticImageEdgeSize_y)

MapImageReturn = urllib.urlretrieve(MapImgageURL, "/Users/martin/Desktop/GDELT_Data/map/staticmap.png")[0]
GMImageArray = mpimg.imread(MapImageReturn)

imgplot = plt.imshow(GMImageArray)

#api.geocode("somwhere")
#api.reverse(51.123, 21.123)
